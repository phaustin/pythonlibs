# %%
# !ls *db
# Out:
# du_nchaparr_tera2.db  files_tera2_nchaparr.db  ls_tera2_nchaparr.db
# du_tera2_nchaparr.db  files_tera2_phil.db      tera_phil_du_list.db
# du_tera_root.db       files_tera_phil.db       tera_phil_file_list.db

# %%
from sqlalchemy import and_
from sqlalchemy.orm import sessionmaker
import dataset
from pandas import DataFrame, Series
import pandas as pd
pd.options.display.float_format = '{:6.3f}'.format

# %%
def get_frame_from_query(the_query):
    """make a dataframe from an sqlalchemy query"""
    colnames=[col['name'] for col in the_query.column_descriptions]
    df=DataFrame.from_records(list(the_query),columns=colnames)
    return df

# %%
file_db='du_tera_root.db'

# %%
dbstring='sqlite:///{:s}'.format(file_db)
db = dataset.connect(dbstring)
session=sessionmaker(bind=db.engine)
thesession=session()

# %%
direc_table=db.metadata.tables['direcs']

# %%
large_query=thesession.query(direc_table).filter(direc_table.c.level == 6)

# %%
df_files=get_frame_from_query(large_query)

# %%
df_files['size']=df_files['size']*1.e-6

# %%
df_files['size'].sum()
# Out:
# 8526.368696000216

# %%
df_files=df_files.sort(columns='size',ascending=False)

# %% [markdown]
#     def add_col(df_files):
#         df_files['size_print']=df_files['size'].map('{:6.3f}'.format)
#         return df_files

# %%
new_df=add_col(df_files)

# %%
new_df.columns
# Out:
# Index([u'id', u'directory', u'level', u'size', u'size_print'], dtype='object')

# %%
hit=df_files['directory'].str.contains('/phil/')
phil_df=df_files[hit]
phil_df[1:]['size'].sum()
# Out:
# 3183.6202639998755

# %%
phil_df
# Out:
#           id                                          directory  level  \
# 5933  163244      /tera/phil/nchaparr/python/Plotting/Sep302013      6
# 5952  163803       /tera/phil/nchaparr/python/Plotting/Nov42013      6
# 5959  163931    /tera/phil/nchaparr/python/Plotting/Nov302013_1      6
# 5967  163979      /tera/phil/nchaparr/python/Plotting/Oct282013      6
# 5948  163375      /tera/phil/nchaparr/python/Plotting/Aug152013      6
# 5932  163220      /tera/phil/nchaparr/python/Plotting/Nov272013      6
# 5927  163069      /tera/phil/nchaparr/python/Plotting/Oct312013      6
# 5250  159789                /tera/phil/austinp/repos/SAM/OUT_3D      6
# 5906  162962           /tera/phil/nchaparr/SAM2/sam_main/python      6
# 2379   94073  /tera/roc_space2/phil/mvandenb/ladsweb.nascom....      6
# 2687  101558    /tera/roc_space2/phil/samcompare/mingsam/DATA3D      6
# 5937  163272     /tera/phil/nchaparr/python/Plotting/July172013      6
# 2726  101619     /tera/roc_space2/phil/samcompare/SAM6.4/DATA3D      6
# 5942  163302      /tera/phil/nchaparr/python/Plotting/July92013      6
# 2581  101104    /tera/roc_space2/phil/phil-repo/SAM6.7.5/OUT_3D      6
# 5963  163970      /tera/phil/nchaparr/python/Plotting/May172013      6
# 1725   38343  /tera/roc_space2/kite_backups/level_0_kite_use...      6
# 2649  101479   /tera/roc_space2/phil/skrayenh/ARMDIURNAL/DATA3D      6
# 2705  101589  /tera/roc_space2/phil/samcompare/SAM6.6.5a/DATA3D      6
# 2523  100497            /tera/roc_space2/phil/sam/philruns/RUN1      6
# 3398  110326          /tera/roc_space/phil/medusa/qgeng/WORKDIR      6
# 3834  119262  /tera/roc_space/phil/install_2009_02_12/RUN1/D...      6
# 4415  146914            /tera/roc_space/phil/moc2/foster/b301nc      6
# 1773   51172  /tera/roc_space2/kite_backups/level_0_kite_use...      6
# 2549  100709  /tera/roc_space2/phil/climate_data/eraInterim/...      6
# 5922  163027      /tera/phil/nchaparr/python/Plotting/Apr262013      6
# 2551  100793  /tera/roc_space2/phil/climate_data/single_colu...      6
# 4759  151413          /tera/roc_space/phil/xue/data/gcmdata_15h      6
# 5923  163058      /tera/phil/nchaparr/python/Plotting/May302013      6
# 5912  163001      /tera/phil/nchaparr/python/Plotting/May282013      6
# 4765  151420             /tera/roc_space/phil/xue/data/icpp_cma      6
# 2564  101069   /tera/roc_space2/phil/climate_data/ipcc/icpp_cma      6
# 4444  147000          /tera/roc_space/phil/feedback/rico/OUT_3D      6
# 6039  165000              /tera/phil/xue_git/fresh/data/forcing      6
# 6070  165324           /tera/phil/xue_git/untangle/data/forcing      6
# 6021  164739       /tera/phil/xue_git/untangletemp/data/forcing      6
# 6718  166582     /tera/phil/data.eol.ucar.edu/pub/download/data      6
# 2561  101065  /tera/roc_space2/phil/climate_data/ipcc/ipcc_gfdl      6
# 4762  151416            /tera/roc_space/phil/xue/data/ipcc_gfdl      6
# 5935  163256      /tera/phil/nchaparr/python/Plotting/May312013      6
# 1838   75516  /tera/roc_space2/kite_backups/level_0_kite_use...      6
# 4810  151918  /tera/roc_space/phil/PART5-ncep/EXPS/NCEP-9798...      6
# 4803  151874  /tera/roc_space/phil/PART5-ncep/EXPS/NCEP-clim...      6
# 1794   53549  /tera/roc_space2/kite_backups/level_0_kite_use...      6
# 5947  163340      /tera/phil/nchaparr/python/Plotting/May272013      6
# 2560  101064  /tera/roc_space2/phil/climate_data/ipcc/ipcc_ukmo      6
# 4761  151415            /tera/roc_space/phil/xue/data/ipcc_ukmo      6
# 2577  101098   /tera/roc_space2/phil/phil-repo/SAM6.7.5/RESTART      6
# 2546  100706  /tera/roc_space2/phil/climate_data/eraInterim/...      6
# 5715  161292            /tera/phil/scm16/scm16/data/gcm16_input      6
# 4746  150604      /tera/roc_space/phil/xue/test_for_phil/McGill      6
# 4813  151953  /tera/roc_space/phil/PART5-ncep/EXPS/NCEP-9798...      6
# 4811  151931  /tera/roc_space/phil/PART5-ncep/EXPS/NCEP-clim...      6
# 4730  147741  /tera/roc_space/phil/xue/test_for_phil/testwri...      6
# 3466  110628  /tera/roc_space/phil/testnew_for_phil/testwrit...      6
# 4750  151185    /tera/roc_space/phil/xue/test_for_phil/scmtools      6
# 3657  114121  /tera/roc_space/phil/testnew_for_phil/scmtools...      6
# 3442  110491          /tera/roc_space/phil/ihop/collection5/srb      6
# 2556  100799    /tera/roc_space2/phil/climate_data/era40/netCDF      6
# 1798   73695  /tera/roc_space2/kite_backups/level_0_kite_use...      6
#          ...                                                ...    ...
#
#          size size_print
# 5933 1395.051   1395.051
# 5952 1176.872   1176.872
# 5959  403.640    403.640
# 5967  402.221    402.221
# 5948  139.382    139.382
# 5932  133.532    133.532
# 5927  129.461    129.461
# 5250  108.932    108.932
# 5906   70.088     70.088
# 2379   58.006     58.006
# 2687   26.766     26.766
# 5937   23.220     23.220
# 2726   17.910     17.910
# 5942   17.655     17.655
# 2581   17.645     17.645
# 5963   16.141     16.141
# 1725   15.695     15.695
# 2649   15.382     15.382
# 2705   12.204     12.204
# 2523   12.075     12.075
# 3398   11.692     11.692
# 3834   10.896     10.896
# 4415   10.589     10.589
# 1773   10.404     10.404
# 2549    9.109      9.109
# 5922    8.955      8.955
# 2551    7.957      7.957
# 4759    7.957      7.957
# 5923    7.513      7.513
# 5912    7.513      7.513
# 4765    7.024      7.024
# 2564    7.024      7.024
# 4444    6.923      6.923
# 6039    6.131      6.131
# 6070    6.131      6.131
# 6021    6.131      6.131
# 6718    5.614      5.614
# 2561    5.120      5.120
# 4762    5.120      5.120
# 5935    4.977      4.977
# 1838    4.632      4.632
# 4810    4.563      4.563
# 4803    4.562      4.562
# 1794    4.383      4.383
# 5947    4.144      4.144
# 2560    4.028      4.028
# 4761    4.028      4.028
# 2577    4.015      4.015
# 2546    4.006      4.006
# 5715    3.915      3.915
# 4746    3.850      3.850
# 4813    3.724      3.724
# 4811    3.224      3.224
# 4730    3.128      3.128
# 3466    3.079      3.079
# 4750    2.903      2.903
# 3657    2.822      2.822
# 3442    2.722      2.722
# 2556    2.708      2.708
# 1798    2.674      2.674
#           ...        ...
#
# [4586 rows x 5 columns]

# %%
print "a=",5
# Out:
# a= 5
