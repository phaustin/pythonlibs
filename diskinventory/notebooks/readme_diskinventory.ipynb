# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # disk cleanup workflow

# %%
import context
import numpy as np

# %%
from diskinventory.parse_files import read_ls, read_du
print(dir(context))
# Out:
# ['Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'curr_dir', 'data_dir', 'root_dir', 'sep', 'site', 'sys']
# /Users/phil/new37/envs/e213/lib/python3.6/site-packages/dask/config.py:125: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
du_file = context.data_dir / 'rail_users_du.txt'
du_df = read_du(du_file)
groups = du_df.groupby('level')

# %%
type(dict)
# Out:
# type

# %%
out = dict(list(groups))

# %%
level3=out[3].sort_values('size',ascending=False)
level3['size']=level3['size']*1.e-6
level3
# Out:
#                                                 directory  level        size
# 66576                                   /Users/phil/repos      3  119.625420
# 172485                                /Users/phil/Library      3   70.217752
# 6030                                /Users/phil/Nextcloud      3   31.130332
# 183377                                /Users/phil/Dropbox      3   22.315280
# 80925                                /Users/phil/ownCloud      3   12.114884
# 228753                              /Users/phil/Downloads      3    9.101844
# 223006                                  /Users/phil/new37      3    7.890144
# 191440                              /Users/phil/Documents      3    7.464464
# 172549                                 /Users/phil/gdrive      3    4.835104
# 178901                                 /Users/phil/Movies      3    2.764512
# 72333                         /Users/phil/holdit_wt5yn773      3    1.917984
# 227905                                 /Users/phil/photos      3    1.797596
# 69244                       /Users/phil/e340_2012_archive      3    1.465984
# 68331                                    /Users/phil/temp      3    0.863704
# 72808                               /Users/phil/workspace      3    0.838832
# 187530                       /Users/phil/.vscode-insiders      3    0.711064
# 174078                               /Users/phil/airwatch      3    0.699088
# 227475                                /Users/phil/.vscode      3    0.689380
# 223009  /Users/phil/MYD021KM.A2016224.2100.006.2016225...      3    0.686800
# 172730                        /Users/phil/Calibre_Library      3    0.674960
# 183657                                 /Users/phil/.Trash      3    0.607272
# 72138                                   /Users/phil/mtest      3    0.580188
# 69248                                     /Users/phil/.mu      3    0.547520
# 68793                                     /Users/phil/bin      3    0.484612
# 173857                               /Users/phil/.dropbox      3    0.480552
# 183817                                /Users/phil/maildir      3    0.400048
# 230182                           /Users/phil/google_drive      3    0.361960
# 180162                           /Users/phil/Applications      3    0.339068
# 72332                                  /Users/phil/.local      3    0.333260
# 229985                                 /Users/phil/.cache      3    0.256636
# ...                                                   ...    ...         ...
# 172619                             /Users/phil/extensions      3    0.000000
# 229997                                /Users/phil/testgit      3    0.000000
# 173342                           /Users/phil/nbextensions      3    0.000000
# 81254                                  /Users/phil/output      3    0.000000
# 230099                                      /Users/phil/l      3    0.000000
# 173560                                  /Users/phil/Sites      3    0.000000
# 81255                                 /Users/phil/.gnome2      3    0.000000
# 81398                           /Users/phil/austinp_files      3    0.000000
# 173643                                   /Users/phil/.esg      3    0.000000
# 81397                                 /Users/phil/bad dir      3    0.000000
# 80926                                 /Users/phil/junkdir      3    0.000000
# 67393                                /Users/phil/.distlib      3    0.000000
# 69250                                    /Users/phil/Mail      3    0.000000
# 227478                               /Users/phil/Dropboxy      3    0.000000
# 66991                                 /Users/phil/.Spyder      3    0.000000
# 68334                              /Users/phil/notes-mode      3    0.000000
# 68336                                 /Users/phil/install      3    0.000000
# 66847                                 /Users/phil/gitjunk      3    0.000000
# 183380                                  /Users/phil/.gist      3    0.000000
# 81362                              /Users/phil/nbstripout      3    0.000000
# 68856                     /Users/phil/.QtWebEngineProcess      3    0.000000
# 174079                   /Users/phil/carbon_problem_files      3    0.000000
# 68859                 /Users/phil/ladsweb.nascom.nasa.gov      3    0.000000
# 174015                                /Users/phil/figures      3    0.000000
# 68860                                  /Users/phil/rtmdir      3    0.000000
# 173952                                /Users/phil/.idlerc      3    0.000000
# 173863                                /Users/phil/.tmpdir      3    0.000000
# 229986                                  /Users/phil/baddy      3    0.000000
# 229987                                /Users/phil/backups      3    0.000000
# 229988                                 /Users/phil/.abook      3    0.000000
#
# [238 rows x 3 columns]

# %%
# Out:
# 305.17304399999995

# %% [markdown]
# ##
#
# ```
# sudo gls -R -l -Q --time-style=full-iso  /Users/ > /Users/phil/repos/pythonlibs/diskinventory/datadir/rail_users_ls.txt
# sudo gdu -k /Users/phil  > /Users/phil/repos/pythonlibs/diskinventory/datadir/rail_users_du.txt
# ```
